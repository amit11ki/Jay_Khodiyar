# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r"C:\Users\amit\Downloads\test.csv")

# %%
subcategories_to_move = [
    "RapeGang Rape RGRSexually Abusive Content",
    "Sexually Explicit Act",
    "Child Pornography CPChild Sexual Abuse Material CSAM",
    "Sexually Obscene material"
]

mask = data['category'].isin(subcategories_to_move) & data['sub_category'].isna()

# Step 2: Update the Subcategory column with the values from the Category column for these rows
data.loc[mask, 'sub_category'] = data.loc[mask, 'category']

# Step 3: Set the Category for these rows to "Women/Child Related Crime"
data.loc[mask, 'category'] = 'Women/Child Related Crime'

# Fill remaining nulls in Subcategory with 'Unknown' (if needed)
data['sub_category'].fillna('Unknown', inplace=True)

# Display the transformed dataset (for verification)
print(data[mask])

data.to_csv('updated_data.csv', index=False)
# Out:
# C:\Users\amit\AppData\Local\Temp\ipykernel_19112\477270758.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['sub_category'].fillna('Unknown', inplace=True)
#                         category  \
# 0      Women/Child Related Crime
# 10     Women/Child Related Crime
# 12     Women/Child Related Crime
# 25     Women/Child Related Crime
# 61     Women/Child Related Crime
# ...                          ...
# 31156  Women/Child Related Crime
# 31182  Women/Child Related Crime
# 31183  Women/Child Related Crime
# 31191  Women/Child Related Crime
# 31209  Women/Child Related Crime
#
#                                             sub_category  \
# 0              RapeGang Rape RGRSexually Abusive Content
# 10                                 Sexually Explicit Act
# 12                             Sexually Obscene material
# 25     Child Pornography CPChild Sexual Abuse Materia...
# 61             RapeGang Rape RGRSexually Abusive Content
# ...                                                  ...
# 31156          RapeGang Rape RGRSexually Abusive Content
# 31182          RapeGang Rape RGRSexually Abusive Content
# 31183                              Sexually Explicit Act
# 31191                              Sexually Explicit Act
# 31209          RapeGang Rape RGRSexually Abusive Content
#
#                                       crimeaditionalinfo
# 0      Sir namaskar  mein Ranjit Kumar PatraPaise neh...
# 10     Hello sir they are sending friend request and ...
# 12     He was called from Maharashtra and created fak...
# 25     The above mentioned porn site contains some vi...
# 61     Respected Sir\r\n\r\nA very serious matter I w...
# ...                                                  ...
# 31156  Respected Sir\r\n\r\nA very serious matter I w...
# 31182  Respected Sir\r\n\r\nA very serious matter I w...
# 31183  Sir I have lost nearly  for a mistake I have m...
# 31191  Im from chalakudy  this is a complaint about m...
# 31209  Respected Sir\r\n\r\nA very serious matter I w...
#
# [2236 rows x 3 columns]

# %%
category_c=data['category'].value_counts()
print('category:',category_c)
# Out:
# category: category
# Online Financial Fraud                            18896
# Online and Social Media Related Crime              4139
# Any Other Cyber Crime                              3670
# Women/Child Related Crime                          2236
# Cyber Attack/ Dependent Crimes                     1261
# Hacking  Damage to computercomputer system etc      592
# Cryptocurrency Crime                                166
# Online Gambling  Betting                            134
# Online Cyber Trafficking                             61
# Cyber Terrorism                                      52
# Ransomware                                           18
# Crime Against Women & Children                        4
# Name: count, dtype: int64

# %%
#
# Creating a DataFrame


# Renaming specified categories
data['category'] = data['category'].replace(
    {
        'Hacking  Damage to computercomputer system etc': 'Other Cyber Crime',
        'Online Cyber Trafficking': 'Other Cyber Crime',
        'Online and Social Media Related Crime': 'Other Cyber Crime',
        'Ransomware': 'Other Cyber Crime',
        'Report Unlawful Content': 'Other Cyber Crime',
        'Any Other Cyber Crime': 'Other Cyber Crime',
        'Cyber Attack/ Dependent Crimes': 'Other Cyber Crime',
        'Cyber Terrorism': 'Other Cyber Crime',
        'Online Financial Fraud': 'Financial Fraud Crimes',
        'Cryptocurrency Crime': 'Financial Fraud Crimes',
        'Online Gambling  Betting': 'Financial Fraud Crimes',
        'Crime Against Women & Children':"Women/Child Related Crime"
        
    }
)


# Display the updated DataFrame
print(data.head(35))
# Out:
#                      category  \
# 0   Women/Child Related Crime
# 1      Financial Fraud Crimes
# 2           Other Cyber Crime
# 3      Financial Fraud Crimes
# 4           Other Cyber Crime
# 5      Financial Fraud Crimes
# 6           Other Cyber Crime
# 7      Financial Fraud Crimes
# 8      Financial Fraud Crimes
# 9      Financial Fraud Crimes
# 10  Women/Child Related Crime
# 11          Other Cyber Crime
# 12  Women/Child Related Crime
# 13     Financial Fraud Crimes
# 14     Financial Fraud Crimes
# 15     Financial Fraud Crimes
# 16          Other Cyber Crime
# 17     Financial Fraud Crimes
# 18          Other Cyber Crime
# 19     Financial Fraud Crimes
# 20     Financial Fraud Crimes
# 21     Financial Fraud Crimes
# 22     Financial Fraud Crimes
# 23     Financial Fraud Crimes
# 24          Other Cyber Crime
# 25  Women/Child Related Crime
# 26          Other Cyber Crime
# 27          Other Cyber Crime
# 28     Financial Fraud Crimes
# 29     Financial Fraud Crimes
# 30     Financial Fraud Crimes
# 31          Other Cyber Crime
# 32     Financial Fraud Crimes
# 33          Other Cyber Crime
# 34          Other Cyber Crime
#
#                                          sub_category  \
# 0           RapeGang Rape RGRSexually Abusive Content
# 1                DebitCredit Card FraudSim Swap Fraud
# 2                                       SQL Injection
# 3                                   Fraud CallVishing
# 4                                               Other
# 5                      Internet Banking Related Fraud
# 6                      Unauthorised AccessData Breach
# 7                                  UPI Related Frauds
# 8                      Internet Banking Related Fraud
# 9                DebitCredit Card FraudSim Swap Fraud
# 10                              Sexually Explicit Act
# 11            Damage to computer computer systems etc
# 12                          Sexually Obscene material
# 13                                 UPI Related Frauds
# 14                                 UPI Related Frauds
# 15                                  Fraud CallVishing
# 16                          Cheating by Impersonation
# 17                                 UPI Related Frauds
# 18                                              Other
# 19               DebitCredit Card FraudSim Swap Fraud
# 20               DebitCredit Card FraudSim Swap Fraud
# 21                                 UPI Related Frauds
# 22                                 UPI Related Frauds
# 23                                 UPI Related Frauds
# 24                                              Other
# 25  Child Pornography CPChild Sexual Abuse Materia...
# 26                                              Other
# 27                                     Malware Attack
# 28                                 UPI Related Frauds
# 29                              EWallet Related Fraud
# 30                                 UPI Related Frauds
# 31                                     Malware Attack
# 32                                 UPI Related Frauds
# 33                                     EMail Phishing
# 34                     Profile Hacking Identity Theft
#
#                                    crimeaditionalinfo
# 0   Sir namaskar  mein Ranjit Kumar PatraPaise neh...
# 1           KOTAK MAHINDRA BANK FRAUD\r\nFRAUD AMOUNT
# 2   The issue actually started when I got this ema...
# 3   I am amit kumar from karwi chitrakoot I am tot...
# 4   I have ordered  saree and  blouse from rinki s...
# 5   My salary of amount  has to be credited to my ...
# 6   Due to some financial crisis I have applied lo...
# 7   a person called and told that i won a gift car...
# 8   NameManik Varban SO Nirmal Varban \r\nAddkhara...
# 9   Dear Sir\r\n             Please stop the fraud...
# 10  Hello sir they are sending friend request and ...
# 11  PLEASE READ ABOVE ATTACHED COMPLAINT OVERVIEW\...
# 12  He was called from Maharashtra and created fak...
# 13  Identity theft   Fake Customer Care Service Fr...
# 14  At first\r\nI had received a WhatsApp from  an...
# 15  spam message i recieve msg from unwanted numbe...
# 16          SO                                AGRI...
# 17  FRAUD THROUGH  UPI GOOGLEPAY\r\nBANK \tPunjab ...
# 18  Missing UPI idvenkatasubbareddyybl this not my...
# 19   time  may be incoming call on pooja sharma as...
# 20  I am Rohit Pandharkar from Mumbai Someone has ...
# 21                                   financial fraud
# 22
# 23  Dear Sir\r\n             Please stop the fraud...
# 24                                                ...
# 25  The above mentioned porn site contains some vi...
# 26                       elza energy did online fraud
# 27  The issue actually started when I got this ema...
# 28  FRAUD THROUGH  Phone Pe\t\t\r\nBANK  BANK OF B...
# 29                                         Upi fraud
# 30  FRAUD THROUGH UPI FRAUD PHONE PE\r\nBANK NAME ...
# 31  The issue actually started when I got this ema...
# 32  I received a advertisement on Google then I am...
# 33  Dear sir\r\nMera name simarjeet pannu h meri G...
# 34  all my social media accounts were hacked and m...

# %%
category_c=data['category'].value_counts()
print('category:',category_c)
# Out:
# category: category
# Financial Fraud Crimes       19196
# Other Cyber Crime             9793
# Women/Child Related Crime     2240
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# category              0
# sub_category          0
# crimeaditionalinfo    7
# dtype: int64

# %%
data['crimeaditionalinfo'].dropna()
# Out:
# 0        Sir namaskar  mein Ranjit Kumar PatraPaise neh...
# 1                KOTAK MAHINDRA BANK FRAUD\r\nFRAUD AMOUNT
# 2        The issue actually started when I got this ema...
# 3        I am amit kumar from karwi chitrakoot I am tot...
# 4        I have ordered  saree and  blouse from rinki s...
#                                ...
# 31224    A lady named Rashmi probably a fake name had c...
# 31225    I am Mr Chokhe Ram  Two pers mobile number wer...
# 31226    Mai Bibekbraj maine pahle ki complain kar chuk...
# 31227    received URL link for updating KYC from mobile...
# 31228    I saw add on facebook for job placement and I ...
# Name: crimeaditionalinfo, Length: 31222, dtype: object

# %%
data.isnull().sum()
# Out:
# category              0
# sub_category          0
# crimeaditionalinfo    7
# dtype: int64

# %%
# Drop rows with missing text or label values, if any
data.dropna(subset=['crimeaditionalinfo', 'category'], inplace=True)

# %%
data.isnull().sum()
# Out:
# category              0
# sub_category          0
# crimeaditionalinfo    0
# dtype: int64

# %%
category_c=data['category'].value_counts()
print('category:',category_c)
# Out:
# category: category
# Financial Fraud Crimes       19190
# Other Cyber Crime             9793
# Women/Child Related Crime     2239
# Name: count, dtype: int64

# %%
cat_c=data["category"].value_counts()
print(cat_c)
cat_cc=data["sub_category"].value_counts()
print(cat_cc)
# Out:
# category
# Financial Fraud Crimes       19190
# Other Cyber Crime             9793
# Women/Child Related Crime     2239
# Name: count, dtype: int64
# sub_category
# UPI Related Frauds                                                      8886
# Other                                                                   3670
# DebitCredit Card FraudSim Swap Fraud                                    3555
# Internet Banking Related Fraud                                          2973
# Fraud CallVishing                                                       1826
# Cyber Bullying  Stalking  Sexting                                       1366
# EWallet Related Fraud                                                   1338
# RapeGang Rape RGRSexually Abusive Content                                912
# FakeImpersonating Profile                                                763
# Profile Hacking Identity Theft                                           751
# Cheating by Impersonation                                                719
# Sexually Obscene material                                                665
# Sexually Explicit Act                                                    535
# Unauthorised AccessData Breach                                           370
# Online Job Fraud                                                         294
# DematDepository Fraud                                                    222
# Hacking/Defacement                                                       200
# Tampering with computer source documents                                 194
# Denial of Service (DoS)/Distributed Denial of Service (DDOS) attacks     187
# Ransomware Attack                                                        186
# Data Breach/Theft                                                        171
# Malware Attack                                                           170
# SQL Injection                                                            167
# Cryptocurrency Fraud                                                     166
# Online Gambling  Betting                                                 134
# Provocative Speech for unlawful acts                                     130
# Email Hacking                                                            130
# Child Pornography CPChild Sexual Abuse Material CSAM                     123
# Business Email CompromiseEmail Takeover                                   90
# Online Trafficking                                                        61
# EMail Phishing                                                            54
# Cyber Terrorism                                                           52
# Damage to computer computer systems etc                                   39
# Website DefacementHacking                                                 39
# Online Matrimonial Fraud                                                  38
# Ransomware                                                                18
# Impersonating Email                                                       13
# Intimidating Email                                                        11
# Computer Generated CSAM/CSEM                                               2
# Cyber Blackmailing & Threatening                                           1
# Sexual Harassment                                                          1
# Name: count, dtype: int64

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

# Download stopwords and wordnet if not already downloaded
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Function for text cleaning
def clean_text(text):
    # Remove punctuation
    text = re.sub(f"[{string.punctuation}]", " ", text)
    # Convert text to lowercase
    text = text.lower()
    # Tokenize and remove stopwords, then lemmatize
    words = [lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words]
    return " ".join(words)

# Apply cleaning function to the 'crimeaditionalinfo' column
data['crimeaditionalinfo'] = data['crimeaditionalinfo'].apply(clean_text)
print(data['crimeaditionalinfo'].head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    sir namaskar mein ranjit kumar patrapaise nehi...
# 1               kotak mahindra bank fraud fraud amount
# 2    issue actually started got email first glance ...
# 3    amit kumar karwi chitrakoot totally depressed ...
# 4    ordered saree blouse rinki sur paid amount tak...
# Name: crimeaditionalinfo, dtype: object

# %%
df= data

# %%
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample
import pandas as pd

# Load your dataset
# df = pd.read_csv('your_data.csv')  # Assuming df is already loaded as per your example

# Check initial distribution
print("Initial Main Category Distribution:\n", df['category'].value_counts())
print("Initial Subcategory Distribution:\n", df['sub_category'].value_counts())

# Step 1: Balance Main Categories
# Define the target count for each main category
target_count = df['category'].value_counts().max()  # Use max count as the target for all categories

# Separate each main category and apply resampling
balanced_categories = []
for category in df['category'].unique():
    category_df = df[df['category'] == category]
    
    # Perform oversampling within each category to match the target count
    balanced_category_df = resample(category_df, replace=True, n_samples=target_count, random_state=42)
    balanced_categories.append(balanced_category_df)

# Concatenate the balanced main categories
df_balanced = pd.concat(balanced_categories)

# Step 2: Balance Subcategories within Each Main Category
final_balanced = []
for category in df_balanced['category'].unique():
    category_df = df_balanced[df_balanced['category'] == category]
    max_subcat_count = category_df['sub_category'].value_counts().max()  # Target count within each subcategory
    
    # Balance each subcategory within the main category
    balanced_subcategories = []
    for subcategory in category_df['sub_category'].unique():
        subcat_df = category_df[category_df['sub_category'] == subcategory]
        
        # Use SMOTE if the subcategory has fewer samples, otherwise resample
        if len(subcat_df) < max_subcat_count:
            # Applying SMOTE to numeric vector representations would require preprocessing (TF-IDF, embeddings, etc.)
            # For simplicity, let's assume resampling here, as SMOTE directly on text is not ideal
            resampled_subcat_df = resample(subcat_df, replace=True, n_samples=max_subcat_count, random_state=42)
        else:
            resampled_subcat_df = subcat_df  # Keep as is if already balanced
        
        balanced_subcategories.append(resampled_subcat_df)
    
    # Concatenate balanced subcategories for each main category
    final_balanced.append(pd.concat(balanced_subcategories))

# Concatenate all main categories with balanced subcategories
df_final_balanced = pd.concat(final_balanced)

# Check the final balanced distribution
print("Balanced Main Category Distribution:\n", df_final_balanced['category'].value_counts())
print("Balanced Subcategory Distribution:\n", df_final_balanced['sub_category'].value_counts())
# Out:
# Initial Main Category Distribution:
#  category
# Financial Fraud Crimes       19190
# Other Cyber Crime             9793
# Women/Child Related Crime     2239
# Name: count, dtype: int64
# Initial Subcategory Distribution:
#  sub_category
# UPI Related Frauds                                                      8886
# Other                                                                   3670
# DebitCredit Card FraudSim Swap Fraud                                    3555
# Internet Banking Related Fraud                                          2973
# Fraud CallVishing                                                       1826
# Cyber Bullying  Stalking  Sexting                                       1366
# EWallet Related Fraud                                                   1338
# RapeGang Rape RGRSexually Abusive Content                                912
# FakeImpersonating Profile                                                763
# Profile Hacking Identity Theft                                           751
# Cheating by Impersonation                                                719
# Sexually Obscene material                                                665
# Sexually Explicit Act                                                    535
# Unauthorised AccessData Breach                                           370
# Online Job Fraud                                                         294
# DematDepository Fraud                                                    222
# Hacking/Defacement                                                       200
# Tampering with computer source documents                                 194
# Denial of Service (DoS)/Distributed Denial of Service (DDOS) attacks     187
# Ransomware Attack                                                        186
# Data Breach/Theft                                                        171
# Malware Attack                                                           170
# SQL Injection                                                            167
# Cryptocurrency Fraud                                                     166
# Online Gambling  Betting                                                 134
# Provocative Speech for unlawful acts                                     130
# Email Hacking                                                            130
# Child Pornography CPChild Sexual Abuse Material CSAM                     123
# Business Email CompromiseEmail Takeover                                   90
# Online Trafficking                                                        61
# EMail Phishing                                                            54
# Cyber Terrorism                                                           52
# Damage to computer computer systems etc                                   39
# Website DefacementHacking                                                 39
# Online Matrimonial Fraud                                                  38
# Ransomware                                                                18
# Impersonating Email                                                       13
# Intimidating Email                                                        11
# Computer Generated CSAM/CSEM                                               2
# Cyber Blackmailing & Threatening                                           1
# Sexual Harassment                                                          1
# Name: count, dtype: int64
# Balanced Main Category Distribution:
#  category
# Other Cyber Crime            178475
# Financial Fraud Crimes        79677
# Women/Child Related Crime     54908
# Name: count, dtype: int64
# Balanced Subcategory Distribution:
#  sub_category
# DematDepository Fraud                                                   8853
# Fraud CallVishing                                                       8853
# Cryptocurrency Fraud                                                    8853
# Business Email CompromiseEmail Takeover                                 8853
# Internet Banking Related Fraud                                          8853
# Online Gambling  Betting                                                8853
# EWallet Related Fraud                                                   8853
# DebitCredit Card FraudSim Swap Fraud                                    8853
# UPI Related Frauds                                                      8853
# Sexually Obscene material                                               7844
# RapeGang Rape RGRSexually Abusive Content                               7844
# Cyber Blackmailing & Threatening                                        7844
# Sexual Harassment                                                       7844
# Child Pornography CPChild Sexual Abuse Material CSAM                    7844
# Computer Generated CSAM/CSEM                                            7844
# Sexually Explicit Act                                                   7844
# Tampering with computer source documents                                7139
# Damage to computer computer systems etc                                 7139
# Ransomware Attack                                                       7139
# Online Matrimonial Fraud                                                7139
# Online Trafficking                                                      7139
# Ransomware                                                              7139
# EMail Phishing                                                          7139
# Impersonating Email                                                     7139
# Cyber Terrorism                                                         7139
# Website DefacementHacking                                               7139
# Denial of Service (DoS)/Distributed Denial of Service (DDOS) attacks    7139
# Provocative Speech for unlawful acts                                    7139
# Unauthorised AccessData Breach                                          7139
# SQL Injection                                                           7139
# Profile Hacking Identity Theft                                          7139
# Malware Attack                                                          7139
# Cheating by Impersonation                                               7139
# Online Job Fraud                                                        7139
# Cyber Bullying  Stalking  Sexting                                       7139
# Data Breach/Theft                                                       7139
# Other                                                                   7139
# Hacking/Defacement                                                      7139
# FakeImpersonating Profile                                               7139
# Email Hacking                                                           7139
# Intimidating Email                                                      7139
# Name: count, dtype: int64

# %%
import pandas as pd



# Create a mapping of old sub-category names to new sub-category names
sub_category_mapping = {
    'Cyber Bullying  Stalking  Sexting': 'Cyber Bullying/Stalking/Sexting',
    'Fraud CallVishing': 'Fraud Call/Vishing',
    'Online Gambling  Betting': 'Online Gambling/Betting Fraud',
    'Online Job Fraud': 'Online Job Fraud',
    'UPI Related Frauds': 'UPI-Related Frauds',
    'Internet Banking Related Fraud': 'Internet Banking-Related Fraud',
    'RapeGang Rape RGRSexually Abusive Content': 'Rape/Gang Rape-Sexually Abusive Content',
    'Other': 'Any Other Cyber Crime',
    'Profile Hacking Identity Theft': 'Profile Hacking/Identity Theft',
    'DebitCredit Card FraudSim Swap Fraud': 'Debit/Credit Card Fraud',
    'EWallet Related Fraud': 'E-Wallet Related Frauds',
    'Data Breach/Theft': 'Data breaches.',
    'Cheating by Impersonation': 'Cheating by Impersonation',
    'Denial of Service (DoS)/Distributed Denial of Service (DDOS) attacks': 'Denial of Service (DoS) and Distributed Denial of Service (DDoS) attacks.',
    'FakeImpersonating Profile': 'Fake/Impersonating Profile',
    'Cryptocurrency Fraud': 'Cryptocurrency Crime',
    'Sexually Explicit Act': 'Sale, Publishing and Transmitting Obscene Material/Sexually Explicit Material',
    'Sexually Obscene material': 'Sale, Publishing and Transmitting Obscene Material/Sexually Explicit Material',
    'Malware Attack': 'Malware attacks.',
    'Business Email CompromiseEmail Takeover': 'Business Email Compromise/Email Takeover',
    'Email Hacking': 'Email Hacking',
    'Hacking/Defacement': 'Defacement/Hacking',
    'Unauthorised AccessData Breach': 'Unauthorized Access/Data Breach',
    'SQL Injection': 'Attacks on applications (e.g., E-Governance, E-Commerce).',
    'Provocative Speech for unlawful acts': 'Provocative Speech of Unlawful Acts',
    'Ransomware Attack': 'Ransomware',
    'Cyber Terrorism': 'Cyber Terrorism',
    'Child Pornography CPChild Sexual Abuse Material CSAM': 'Child Pornography/Child Sexual Abuse Material (CSAM)',
    'Tampering with computer source documents': 'Tampering with Computer Source Documents',
    'DematDepository Fraud': 'Demat/Depository Fraud',
    'Online Trafficking': 'Online Cyber Trafficking',
    'Online Matrimonial Fraud': 'Online Matrimonial Fraud',
    'Website DefacementHacking': 'Defacement/Hacking',
    'Damage to computer computer systems etc': 'Damage to Computer Systems',
    'Impersonating Email': 'Impersonating Email',
    'EMail Phishing': 'Email Phishing',
    'Ransomware': 'Ransomware',
    'Intimidating Email': 'Intimidating Email',
    'Against Interest of sovereignty or integrity of India': 'Any Other Cyber Crime'
}

# Replace the old sub-category names with the new ones
df_final_balanced['sub_category'] = df_final_balanced['sub_category'].replace(sub_category_mapping)

# Save the updated DataFrame back to a new CSV file

# %%
df_final_balanced['sub_category'].unique().sum()

df_final_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313060 entries, 11843 to 15160
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   category            313060 non-null  object
#  1   sub_category        313060 non-null  object
#  2   crimeaditionalinfo  313060 non-null  object
# dtypes: object(3)
# memory usage: 9.6+ MB

# %%
import pandas as pd
import re

# Function to abbreviate words
def abbreviate(word):
    # Define abbreviations for the top 50 most frequent words
    abbreviations = {
        'account': 'acc',
        'even': 'evn',
        'email': 'eml',
        'everything': 'evrythng',
        'got': 'gt',
        'like': 'lk',
        'number': 'no',
        'one': '1',
        'please': 'pls',
        'money': 'mny',
        'call': 'cll',
        'phone': 'ph',
        'sir': 'sr',
        'help': 'hlp',
        'time': 'tm',
        'amount': 'amt',
        'id': 'ID',
        'people': 'ppl',
        'bank': 'bnk',
        'name': 'nm',
        'message': 'msg',
        'person': 'prsn',
        'r': 'R',
        'started': 'strtd',
        'app': 'app',
        'dont': 'dnt',
        'video': 'vid',
        'detail': 'dtd',
        'anymore': 'nmor',
        'fix': 'fx',
        'came': 'cm',
        'day': 'dy',
        'tried': 'trd',
        'area': 'ara',
        'know': 'knw',
        'pay': 'py',
        'working': 'wkng',
        'problem': 'prblm',
        'whatsapp': 'wapp',
        'thing': 'thng',
        'stange': 'strng',
        'loan': 'ln',
        'fraud': 'frd',
        'friend': 'frnd',
        'hai': 'hi',
        'also': 'als',
        'right': 'rt',
        'locked': 'lckd',
        'asking': 'askg',
        'apart': 'aprt'
    }
    return abbreviations.get(word.lower(), word)

# Function to process text
def process_text(text):
    words = re.findall(r'\b\w+\b', text)
    abbreviated_words = [abbreviate(word) for word in words]
    return ' '.join(abbreviated_words)

# Read the CSV file


# Specify the column you want to abbreviate
column_to_abbreviate = 'crimeaditionalinfo'  # Replace with your column name

# Apply abbreviation to the specified column
df_final_balanced['crimeaditionalinfo'] = df_final_balanced[column_to_abbreviate].apply(process_text)

# Save the result to a new CSV file
df_final_balanced.to_csv('Final_text_2.csv', index=False)

# %%
df_final_balanced.isnull().sum()
# Out:
# category              0
# sub_category          0
# crimeaditionalinfo    0
# dtype: int64

# %%
import pandas as pd

# Assuming your DataFrame is named `df_final_balanced'
df_final_balanced.dropna(subset=['crimeaditionalinfo'], inplace=True)

# %% [raw]
# This is our final dataset after doing all process like text pre-proccesing, balance distribution between sub categories and categories and abriviation

# %%
df_final_balanced.head()
# Out:
#                         category                             sub_category  \
# 11843  Women/Child Related Crime  Rape/Gang Rape-Sexually Abusive Content
# 17834  Women/Child Related Crime  Rape/Gang Rape-Sexually Abusive Content
# 15434  Women/Child Related Crime  Rape/Gang Rape-Sexually Abusive Content
# 29641  Women/Child Related Crime  Rape/Gang Rape-Sexually Abusive Content
# 23258  Women/Child Related Crime  Rape/Gang Rape-Sexually Abusive Content
#
#                                       crimeaditionalinfo
# 11843  They have a group of about ppl including ladie...
# 17834  frd THROUGH EWALLET bnk PAYTM acc no TOTAL amt...
# 15434  Respected sr A very serious matter I want to i...
# 29641  Identity theft Fake Customer Care Service frd ...
# 23258  My Credit Card has been credit with RS on th o...

# %%
cat_c=df_final_balanced["category"].value_counts()
print(cat_c)
cat_cc=df_final_balanced["sub_category"].value_counts()
print(cat_cc)
# Out:
# category
# Other Cyber Crime            178475
# Financial Fraud Crimes        79677
# Women/Child Related Crime     54908
# Name: count, dtype: int64
# sub_category
# Sale, Publishing and Transmitting Obscene Material/Sexually Explicit Material    15688
# Ransomware                                                                       14278
# Defacement/Hacking                                                               14278
# Demat/Depository Fraud                                                            8853
# Business Email Compromise/Email Takeover                                          8853
# Cryptocurrency Crime                                                              8853
# E-Wallet Related Frauds                                                           8853
# Debit/Credit Card Fraud                                                           8853
# UPI-Related Frauds                                                                8853
# Fraud Call/Vishing                                                                8853
# Online Gambling/Betting Fraud                                                     8853
# Internet Banking-Related Fraud                                                    8853
# Rape/Gang Rape-Sexually Abusive Content                                           7844
# Cyber Blackmailing & Threatening                                                  7844
# Computer Generated CSAM/CSEM                                                      7844
# Sexual Harassment                                                                 7844
# Child Pornography/Child Sexual Abuse Material (CSAM)                              7844
# Denial of Service (DoS) and Distributed Denial of Service (DDoS) attacks.         7139
# Cyber Terrorism                                                                   7139
# Impersonating Email                                                               7139
# Email Phishing                                                                    7139
# Tampering with Computer Source Documents                                          7139
# Online Cyber Trafficking                                                          7139
# Online Matrimonial Fraud                                                          7139
# Damage to Computer Systems                                                        7139
# Provocative Speech of Unlawful Acts                                               7139
# Unauthorized Access/Data Breach                                                   7139
# Attacks on applications (e.g., E-Governance, E-Commerce).                         7139
# Profile Hacking/Identity Theft                                                    7139
# Malware attacks.                                                                  7139
# Cheating by Impersonation                                                         7139
# Online Job Fraud                                                                  7139
# Cyber Bullying/Stalking/Sexting                                                   7139
# Data breaches.                                                                    7139
# Any Other Cyber Crime                                                             7139
# Fake/Impersonating Profile                                                        7139
# Email Hacking                                                                     7139
# Intimidating Email                                                                7139
# Name: count, dtype: int64
